# %%
import pandas as pd

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 
data_to_load = "201908-citibike-tripdata.csv"
data_df = pd.read_csv(data_to_load)
data_df.head(10)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           393  2019-08-01 00:00:01.4680  2019-08-01 00:06:35.3780
# 1           627  2019-08-01 00:00:01.9290  2019-08-01 00:10:29.7840
# 2          1132  2019-08-01 00:00:04.0480  2019-08-01 00:18:56.1650
# 3          1780  2019-08-01 00:00:04.1630  2019-08-01 00:29:44.7940
# 4          1517  2019-08-01 00:00:05.4580  2019-08-01 00:25:23.4550
# 5           632  2019-08-01 00:00:11.8060  2019-08-01 00:10:43.9590
# 6           117  2019-08-01 00:00:18.2010  2019-08-01 00:02:15.8600
# 7           378  2019-08-01 00:00:22.0840  2019-08-01 00:06:40.9350
# 8          1102  2019-08-01 00:00:22.0870  2019-08-01 00:18:44.3890
# 9          1733  2019-08-01 00:00:22.5580  2019-08-01 00:29:15.9080
#
#    start station id              start station name  start station latitude  \
# 0             531.0          Forsyth St & Broome St               40.718939
# ...

# %%
# 2. Check the datatypes of your columns. 
data_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id           float64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
# 3. Convert the 'tripduration' column to datetime datatype.
import datetime as dt
data_df['tripduration'] = pd.to_datetime(data_df['tripduration'], unit='s').apply(lambda x: x.strftime("%H:%M:%S"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_with_unit_to_datetime()
#
# ValueError: could not convert string to float: '1970-01-01'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-1ce08c3b7543> in <module>
#       1 # 3. Convert the 'tripduration' column to datetime datatype.
#       2 import datetime as dt
# ----> 3 data_df['tripduration'] = pd.to_datetime(data_df['tripduration'], unit='s').apply(lambda x: x.strftime("%H:%M:%S"))
#       4 data_df['tripduration']
#
# ~\anaconda3\envs\pythonData\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
# ...

# %%
data_df
# Out:
#         tripduration                 starttime                  stoptime  \
# 0         1970-01-01  2019-08-01 00:00:01.4680  2019-08-01 00:06:35.3780
# 1         1970-01-01  2019-08-01 00:00:01.9290  2019-08-01 00:10:29.7840
# 2         1970-01-01  2019-08-01 00:00:04.0480  2019-08-01 00:18:56.1650
# 3         1970-01-01  2019-08-01 00:00:04.1630  2019-08-01 00:29:44.7940
# 4         1970-01-01  2019-08-01 00:00:05.4580  2019-08-01 00:25:23.4550
# ...              ...                       ...                       ...
# 2344219   1970-01-01  2019-08-31 23:59:46.2930  2019-09-01 00:03:23.0360
# 2344220   1970-01-01  2019-08-31 23:59:47.7970  2019-09-01 00:01:45.7440
# 2344221   1970-01-01  2019-08-31 23:59:48.1560  2019-09-01 00:26:42.7760
# 2344222   1970-01-01  2019-08-31 23:59:58.3620  2019-09-01 00:21:39.7040
# 2344223   1970-01-01  2019-08-31 23:59:59.4520  2019-09-01 00:06:59.0210
#
#          start station id              start station name  \
# ...

# %%
# 4. Check the datatypes of your columns. 
data_df.dtypes
# Out:
# tripduration               datetime64[ns]
# starttime                          object
# stoptime                           object
# start station id                  float64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                    float64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                              int64
# dtype: object

# %%
# 5. Export the Dataframe as a new CSV file without the index.
data_df.to_csv('201908-citibike-tripdata_2.csv', index=False)
